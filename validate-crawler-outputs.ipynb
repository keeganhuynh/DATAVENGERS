# %%
import pandas as pd

# %%
df = pd.read_csv("src/database/extracted_files/page_contents.csv")

# %%
df
# Out:
#                                                   url  \
# 0                       https://tuyensinh.uel.edu.vn/
# 1       https://tuyensinh.uel.edu.vn/dao-tao/tien-si/
# 2   https://tuyensinh.uel.edu.vn/dao-tao/vua-lam-v...
# 3   https://tuyensinh.uel.edu.vn/dao-tao/lien-ket-...
# 4   https://tuyensinh.uel.edu.vn/category/thong-ba...
# ..                                                ...
# 59                             https://www.uel.edu.vn
# 60                             https://www.uel.edu.vn
# 61               https://tuyensinh.uel.edu.vn/ve-uel/
# 62  https://tuyensinh.uel.edu.vn/dao-tao/dai-hoc-c...
# 63      https://tuyensinh.uel.edu.vn/dao-tao/thac-si/
#
#                                                 title  \
# 0      Trang Tuyển Sinh Trường Đại học Kinh tế - Luật
# 1                                Tiến sĩ - Tuyển sinh
# 2            Vừa làm vừa học, văn bằng 2 - Tuyển sinh
# 3                       Liên kết quốc tế - Tuyển sinh
# ...

# %%
df1 = pd.read_csv("src/database/extracted_files/page_contents_v1.csv")

# %%
df1
# Out:
#                                                   url  \
# 0                       https://tuyensinh.uel.edu.vn/
# 1                https://tuyensinh.uel.edu.vn/ve-uel/
# 2   https://tuyensinh.uel.edu.vn/dao-tao/dai-hoc-c...
# 3       https://tuyensinh.uel.edu.vn/dao-tao/thac-si/
# 4       https://tuyensinh.uel.edu.vn/dao-tao/tien-si/
# ..                                                ...
# 73                             https://hrm.uel.edu.vn
# 74  https://myuel.uel.edu.vn/Default.aspx?ModuleId...
# 75                             https://lib.uel.edu.vn
# 76  https://qlkh.uel.edu.vn/danh-muc-tap-chi-duoc-...
# 77               https://externalrelations.uel.edu.vn
#
#                                                 title  \
# 0      Trang Tuyển Sinh Trường Đại học Kinh tế - Luật
# 1                                 Về UEL - Tuyển sinh
# 2   Chương Trình Đào Tạo Chính Quy Trường Đại Học ...
# 3                                Thạc sĩ - Tuyển sinh
# ...

# %%
df2 = pd.read_csv("src/database/extracted_files/page_contents_v2.csv")

# %%
df2
# Out:
#                                                    url  \
# 0                        https://tuyensinh.uel.edu.vn/
# 1                 https://tuyensinh.uel.edu.vn/ve-uel/
# 2                              https://kqts.uel.edu.vn
# 3                           https://nhaphoc.uel.edu.vn
# 4                               https://www.uel.edu.vn
# ..                                                 ...
# 131                  https://hr.uel.edu.vn/tuyen-dung/
# 132                           https://psdh.uel.edu.vn/
# 133  https://qlkh.uel.edu.vn/danh-muc-tap-chi-duoc-...
# 134                              https://hr.uel.edu.vn
# 135               https://externalrelations.uel.edu.vn
#
#                                                  title  \
# 0       Trang Tuyển Sinh Trường Đại học Kinh tế - Luật
# 1                                  Về UEL - Tuyển sinh
# 2                               Kết quả Tuyển sinh UEL
# 3                              Cổng nhập học sinh viên
# ...
